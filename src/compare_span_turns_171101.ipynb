# %%
from parse_miami import load_data, load_spkr_info
from get_plots import plot_one_spkr, plot_genders, plot_span_vs_turns, plot_percent_spanish

# %%
data_folder_path = "../data/miami/txt/" # sys.argv[1]
spkr_tsv = '../data/spkr_info_1017.tsv' # sys.argv[2]

all_data = load_data(data_folder_path)
spkr_info = load_spkr_info(spkr_tsv)

# %% [markdown]
# # PLOT 1: Histogram of % of Spanish words in dialogues
# * tune parameter of num_bins for finer detail
# * print-out is to help in selecting particular dialogues to dive into

# %%
num_bins = 10
plot_percent_spanish(all_data, num_bins)
# Out:
# 0.00	sastre13
# 0.26	zeledon2
# 0.41	zeledon13
# 0.44	herring15
# 1.10	herring9
# 1.78	zeledon11
# 3.46	sastre7
# 4.53	herring1
# 6.17	sastre12
# 6.21	herring8
# 7.34	zeledon3
# 8.09	sastre10
# 8.11	sastre4
# 12.21	sastre6
# 13.84	zeledon9
# 14.96	zeledon6
# 17.87	herring7
# 22.65	herring10
# 23.52	herring6
# 26.86	herring13
# 27.90	sastre9
# 38.63	herring17
# 40.60	sastre8
# 41.13	sastre11
# 42.34	herring16
# 42.71	zeledon4
# 45.83	zeledon8
# 55.20	sastre1
# 60.20	herring3
# 67.08	herring14
# 67.81	zeledon5
# 72.92	zeledon7
# 79.63	zeledon1
# 85.72	zeledon14
# 88.24	sastre2
# 89.33	sastre5
# 95.46	herring5
# 96.26	herring12
# 97.94	herring2
# 98.93	herring11

# %% [markdown]
# # Stacked bar charts
# * A span (consecutive # of words in given language) for Spanish _(RED)_ is stacked on top of English _(BLUE)_.
# * Note that the turn # over time for speaker 1 does not correspond with the same turn # for speaker 2.
# * `TODO: align x-axis to compare across speakers over same turn #s`
#
# ## Sastre8 (40% SPA)
# * *AUD* = grandmother (age 63, F)
# * *PAO* = granddaughter (age 13, F)

# %%
plot_span_vs_turns(all_data, 'sastre8')

# %% [markdown]
# ## Zeledon8 (45% SPA)
# * *MAR* = friend 1 (age 45, F)
# * *FLA* = friend 2 (age 42, F)

# %%
plot_span_vs_turns(all_data, 'zeledon8')

# %% [markdown]
# ## Herring10 (22% SPA)
# * 2 females (age ~33)
# * good mix
# * native Miamians

# %%
plot_span_vs_turns(all_data, 'herring10')

# %% [markdown]
# ## Zeledon4 (22% SPA)
# 2 males
# * *ETH* : less Spanish accent; seems to talk more
# * *HEN* : more Spanish accent

# %%
plot_span_vs_turns(all_data, 'zeledon4')

# %% [markdown]
# ## Herring5 (5% SPA)
# * M (*NOA*) & F (*MEG*) (age ~40)
# * married couple?

# %%
plot_span_vs_turns(all_data, 'herring5')

# %% [markdown]
# ## Zeledon9 (13% SPA)
# 2 cousins, kids (somewhat familial but also getting-to-know-each-other)
# * *CHA* : F (age 12)
# * *GIL* : F (age 9)

# %%
plot_span_vs_turns(all_data, 'zeledon9')

# %% [markdown]
# ## Sastre2 (88% SPA)
# * *AVA* : F (age 78)
# * *LUI* : M (age 55)

# %%
plot_span_vs_turns(all_data, 'sastre2')

# %% [markdown]
# ------------
# # NOW IT'S TIME TO PLAY!
# ------------
